# %%
import pandas as pd

df = pd.read_csv("output/simulation_ergebnisse.csv")
df.iloc[0, 1] = "Durchchschnitt"

df = df[df["Unnamed: 1"]=="Durchchschnitt"]

df = df.round(0)
df
# Out:
#                        Szenario      Unnamed: 1            Ausfall  \
# 0               Handlungsoption  Durchchschnitt  Kapazitaetsausbau
# 2             anzahl_besuch_tag  Durchchschnitt              5.497
# 6           anzahl_bewohner_tag  Durchchschnitt             17.551
# 12               fuellmenge_tag  Durchchschnitt            576.688
# 16               kapazitaet_tag  Durchchschnitt             672.03
# 20                   kosten_tag  Durchchschnitt              4.103
# 24  sonderentleerung_kosten_tag  Durchchschnitt                0.0
# 28     ueberfuellung_kosten_tag  Durchchschnitt              3.925
# 32       ueberfuellungsrate_tag  Durchchschnitt             62.151
#
#                 Ausfall.1         Ausfall.2             Besuch  \
# 0   Keine Sondermaßnahmen  Sonderentleerung  Kapazitaetsausbau
# 2                   5.497             5.497              5.503
# 6                  17.551            17.551             17.554
# ...
